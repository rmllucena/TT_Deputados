# %%
import pyodbc
import pandas as pd
import matplotlib

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-BKH32KF4\SQLEXPRESS;'
                      'Database=TT_Deputados;'
                      'Trusted_Connection=yes;')

# %%
cursor = conn.cursor()
cursor.execute('SELECT * FROM TT_Deputados.dbo.[Ano-2021]')

#for row in cursor:
#    print(row)

# %%
for row in cursor:
    print(row)
# Out:
# ('1', 'LIDERANÇA DO CIDADANIA', None, None, None, '2019', 'NA', None, '56', '13', 'FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR', '0', None, 'ARTESANAL SERVICOS DE ALIMENTACAO E BUFFET EIRELI', '228.362.100/0015-7', '104', '4', '2021-03-04T00:00:00', '999.96', '0', '999.96', '3', '2021', '0', None, None, '1751471', None, None, '3453', '7165735', 'http://camara.leg.br/cota-parlamentar/nota-fiscal-eletronica?ideDocumentoFiscal=7165735')
# ('10', 'LIDERANÇA DO CIDADANIA', None, None, None, '2019', 'NA', None, '56', '13', 'FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR', '0', None, 'ARTESANAL SERVICOS DE ALIMENTACAO E BUFFET EIRELI', '228.362.100/0015-7', '163', '4', '2021-05-26T00:00:00', '999.9', '0', '999.9', '5', '2021', '0', None, None, '1767606', None, None, '3453', '7199334', 'http://camara.leg.br/cota-parlamentar/nota-fiscal-eletronica?ideDocumentoFiscal=7199334')
# ...

# %%
type(cursor)

# %%
#import pyodbc
#import pandas as pd

#cnxn = pyodbc.connect(r'DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};'
                      #r'DBQ=C:\users\bartogre\desktop\data.mdb;')
#sql = "Select sum(CYTM), sum(PYTM), BRAND From data Group By BRAND"
#data = pd.read_sql(sql,cnxn)  # without parameters [non-prepared statement]

# %%
sql = 'SELECT * FROM TT_Deputados.dbo.[Ano-2021]'
data = pd.read_sql(sql,conn)

# %%
data
# Out:
#        Registro       txNomeParlamentar          cpf ideCadastro  \
# 0             1  LIDERANÇA DO CIDADANIA         None        None
# 1            10  LIDERANÇA DO CIDADANIA         None        None
# 2           100       LIDERANÇA DO NOVO         None        None
# 3          1000              Norma Ayub  28008901187       66179
# 4         10000           Gastão Vieira   1196553300       74200
# ...         ...                     ...          ...         ...
# 129160    99995       Haroldo Cathedral  11914408691      204465
# 129161    99996       Haroldo Cathedral  11914408691      204465
# 129162    99997       Haroldo Cathedral  11914408691      204465
# 129163    99998       Haroldo Cathedral  11914408691      204465
# 129164    99999       Haroldo Cathedral  11914408691      204465
#
#        nuCarteiraParlamentar nuLegislatura sgUF sgPartido codLegislatura  \
# 0                       None          2019   NA      None             56
# ...

# %%
sql = 'SELECT Registro, txNomeParlamentar, cpf, sgUF, sgPartido, txtDescricao, numMes, numAno, vlrLiquido FROM TT_Deputados.dbo.[Ano-2021]'
data = pd.read_sql(sql,conn)

# %%
data
# Out:
#        Registro       txNomeParlamentar          cpf sgUF sgPartido  \
# 0             1  LIDERANÇA DO CIDADANIA         None   NA      None
# 1            10  LIDERANÇA DO CIDADANIA         None   NA      None
# 2           100       LIDERANÇA DO NOVO         None   NA      None
# 3          1000              Norma Ayub  28008901187   ES       DEM
# 4         10000           Gastão Vieira   1196553300   MA      PROS
# ...         ...                     ...          ...  ...       ...
# 129160    99995       Haroldo Cathedral  11914408691   RR       PSD
# 129161    99996       Haroldo Cathedral  11914408691   RR       PSD
# 129162    99997       Haroldo Cathedral  11914408691   RR       PSD
# 129163    99998       Haroldo Cathedral  11914408691   RR       PSD
# 129164    99999       Haroldo Cathedral  11914408691   RR       PSD
#
#                                              txtDescricao numMes numAno  \
# 0              FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR      3   2021
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
byPartido = data.groupby("sgPartido").sum().sort_values("vlrDocumento", ascending=False)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\romulo\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-74-22143daab20f>", line 1, in <module>
#     byPartido = data.groupby("sgPartido").sum().sort_values("vlrDocumento", ascending=False)
#   File "c:\users\romulo\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py", line 5455, in sort_values
#     k = self._get_label_or_level_values(by, axis=axis)
#   File "c:\users\romulo\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py", line 1684, in _get_label_or_level_values
#     raise KeyError(key)
# KeyError: 'vlrDocumento'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#byPartido.plot.bar(figsize=(20,10))
data['vlrDocumento'] = data['vlrDocumento'].str.replace(',','.')
data
# Out:
#              txNomeParlamentar          cpf sgUF sgPartido  \
# 0       LIDERANÇA DO CIDADANIA         None   NA      None
# 1       LIDERANÇA DO CIDADANIA         None   NA      None
# 2            LIDERANÇA DO NOVO         None   NA      None
# 3                   Norma Ayub  28008901187   ES       DEM
# 4                Gastão Vieira   1196553300   MA      PROS
# ...                        ...          ...  ...       ...
# 129160       Haroldo Cathedral  11914408691   RR       PSD
# 129161       Haroldo Cathedral  11914408691   RR       PSD
# 129162       Haroldo Cathedral  11914408691   RR       PSD
# 129163       Haroldo Cathedral  11914408691   RR       PSD
# 129164       Haroldo Cathedral  11914408691   RR       PSD
#
#                                              txtDescricao numMes numAno  \
# 0              FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR      3   2021
# 1              FORNECIMENTO DE ALIMENTAÇÃO DO PARLAMENTAR      5   2021
# ...

# %%
data['vlrLiquido'] = pd.to_numeric(data['vlrLiquido'], downcast="float")

# %%
ax = data.plot.bar(x='sgPartido', y='vlrLiquido', rot=0)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\romulo\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-77-d13af5254d52>", line 1, in <module>
#     ax = data.plot.bar(x='sgPartido', y='vlrLiquido', rot=0)
#   File "c:\users\romulo\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_core.py", line 1113, in bar
#     return self(kind="bar", x=x, y=y, **kwargs)
#   File "c:\users\romulo\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_core.py", line 955, in __call__
#     return plot_backend.plot(data, kind=kind, **kwargs)
#   File "c:\users\romulo\appdata\local\programs\python\python39\lib\site-packages\pandas\plotting\_matplotlib\__init__.py", line 61, in plot
# ...

# %%
byPartido = data.groupby("sgPartido").sum().sort_values("vlrDocumento", ascending=False)
