# %%
import pyodbc
import pandas as pd
import matplotlib

# %%
df_fato = pd.read_excel('Ano-2021.xlsx')
print(df_fato)
# Out:
#              txNomeParlamentar           cpf  ideCadastro  \
# 0       LIDERANÇA DO CIDADANIA           NaN          NaN
# 1       LIDERANÇA DO CIDADANIA           NaN          NaN
# 2       LIDERANÇA DO CIDADANIA           NaN          NaN
# 3       LIDERANÇA DO CIDADANIA           NaN          NaN
# 4       LIDERANÇA DO CIDADANIA           NaN          NaN
# ...                        ...           ...          ...
# 126091             Pedro Dalua  5.117259e+10     217330.0
# 126092             Pedro Dalua  5.117259e+10     217330.0
# 126093             Pedro Dalua  5.117259e+10     217330.0
# 126094             Pedro Dalua  5.117259e+10     217330.0
# 126095             Pedro Dalua  5.117259e+10     217330.0
#
#         nuCarteiraParlamentar  nuLegislatura sgUF sgPartido  codLegislatura  \
# 0                         NaN           2019  NaN       NaN              56
# 1                         NaN           2019  NaN       NaN              56
# ...

# %%
# Select the ones you want
df_fato2 = df_fato[['txNomeParlamentar, cpf sfUF, sgPartido, txtDescricao, numMes, numAno, CAST(REPLACE("vlrDocumento", ".", ",")]]
print(df_fato2)
# Out:
#              txNomeParlamentar           cpf  ideCadastro  \
# 0       LIDERANÇA DO CIDADANIA           NaN          NaN
# 1       LIDERANÇA DO CIDADANIA           NaN          NaN
# 2       LIDERANÇA DO CIDADANIA           NaN          NaN
# 3       LIDERANÇA DO CIDADANIA           NaN          NaN
# 4       LIDERANÇA DO CIDADANIA           NaN          NaN
# ...                        ...           ...          ...
# 126091             Pedro Dalua  5.117259e+10     217330.0
# 126092             Pedro Dalua  5.117259e+10     217330.0
# 126093             Pedro Dalua  5.117259e+10     217330.0
# 126094             Pedro Dalua  5.117259e+10     217330.0
# 126095             Pedro Dalua  5.117259e+10     217330.0
#
#         nuCarteiraParlamentar  nuLegislatura sgUF sgPartido  codLegislatura  \
# 0                         NaN           2019  NaN       NaN              56
# 1                         NaN           2019  NaN       NaN              56
# ...
