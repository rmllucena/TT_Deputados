3258","3325","3063","1329","2936","3065","3433","2412","3205","3377","3351","3351","3324","3052","3264","2424","3220","1402","3425","2946","2437","3267","3251","3375","3299","2934","3015","3335","3222","3436","3275","3197","3061","3061","3086","3313","3405","1987","3340","3247","3277","3422","2815","1605","3360","3024","3397","3359","1609","2996","3233","3284","3084","2425","3224","1125","1893","3121","2995","2004","3045","3041","3230","3388","1344","3245","1977","2925","3253","3297","1282","3072","3145","3163","1625","3319","1627","2957","3239","1514","3407","3276","3246","3365","2305","3282","2264","2248","3200","1638","3362","2813","1903","1904","2929","3265","3142","2317","2301","3428","3204","1642","220","1910","3349","2986","3199","3316","2386","2243","3280","1645","3260","3355","1458","3416","2339","3363","3209","3332","2300","3312","3083","3426","1918","1677","2962","3081","652","1155","3346","2253","3466","3012","3225","2000","2282","1161","3194","3408","1928","1388","3380","2244","3000","3281","3038","3350","831","2902","1686","1502","2276","3382","2965","3418","2277","3211","3067","169","3062","3286","3046","3235","2969","3293","1286","3278","3341","2922","2998","2430","2871","3208","2945","3385","3066","3404","3296","3288","2395","3417","2940","3419","2958","3162","3389","2265","3271","1697","1947","3323","3330","1699","3059","3395","1951","3356","2280","3291","3196","2954","","2288","2941","2233","1703","1704","3302","1198","3031","3248","3261","2231","3279","2238"]

# %%
tabelafinal = []

for link in range(len(linktransparencia)):

    
    #PEGAR O NOME
  
    
    option = webdriver.ChromeOptions()
    option.add_argument('headless') 
    option.add_argument("enable-automation");
    option.add_argument("--window-size=1920,1080");
    option.add_argument("--no-sandbox");
    option.add_argument("--disable-extensions");
    option.add_argument("--dns-prefetch-disable");
    option.add_argument("--disable-gpu");
    driver = webdriver.Chrome("C:\WebDriver/chromedriver.exe")
    driver.get(linktransparencia[link])
    driver.find_element_by_xpath(
        "//div[@class='mm-page mm-slideout']//div[@class='js-mmenu-container']//div[@class='container-blocos-deputado']")
    element = driver.find_element_by_xpath(
        "//div[@class='mm-page mm-slideout']//div[@class='js-mmenu-container']//div[@class='container-blocos-deputado']")

    html_content = element.get_attribute("outerHTML")

    soup = BeautifulSoup(html_content,'html.parser')

    mylist = soup.find_all('h2', class_='nome-deputado')

    nome=[]
    for x in mylist:
        nome.append(str(x))
    dados = []
    mylist = soup.find_all('li')
    for item in mylist:
        dados.append(item.text)

    
    


    dadosjuntos = [[dados[0].split(":",1)[1],
                    dados[1].split(":",1)[1],
                    dados[2].split(":",1)[1],
                    " ".join(dados[3].split(":",1)[1].replace('\n', '').split()),
                    " ".join(dados[4].split(":",1)[1].replace('\n', '').split()),
                    " ".join(dados[5].split(":",1)[1].replace('\n', '').split())]]
    
    print("printar dadosjuntos")
    print(dadosjuntos)
    driver.close()
    
    #PEGAR ORÇAMENTO
    
    
    
    
    for depcode in range(len(linktransparenciames)):
        mesespecifico = 1

        while mesespecifico < 3:
            linkOrçamento = 'https://www.camara.leg.br/cota-parlamentar/sumarizado?nuDeputadoId={}&dataInicio={}/2020&dataFim={}/2020&despesa=&nomeHospede=&nomePassageiro=&nomeFornecedor=&cnpjFornecedor=&numDocumento=&sguf=&filtroNivel1=1&filtroNivel2=2&filtroNivel3=3'.format(linktransparenciames[depcode],mesespecifico,mesespecifico)
            option = webdriver.ChromeOptions()
            option.add_argument('headless') 
            option.add_argument("enable-automation");
            option.add_argument("--window-size=1920,1080");
            option.add_argument("--no-sandbox");
            option.add_argument("--disable-extensions");
            option.add_argument("--dns-prefetch-disable");
            option.add_argument("--disable-gpu");
            driver = webdriver.Chrome("C:\WebDriver/chromedriver.exe")
            driver.get(linkOrçamento)
            driver.find_element_by_xpath(
                "//div[@class='coluna-centro col-md-9']")
            elementOrçamento = driver.find_element_by_xpath(
                "//div[@class='coluna-centro col-md-9']")

            html_contentOrçamento = elementOrçamento.get_attribute("outerHTML")

            soupOrçamento = BeautifulSoup(html_contentOrçamento,'html.parser')

            Contagem = 0
            tabeladados = []

            while True:
                try:
                    TipoDespesa = soupOrçamento.find(id="linkSumarizado{}".format(Contagem))
                    quotes = [quote for quote in TipoDespesa]
                    Despesa = soupOrçamento.find(id="sumarizado{}".format(Contagem))
                    quotes2 = [quote for quote in Despesa]
                    tabeladados.append([quotes[0].replace('\n', '').replace('\t', ''),quotes2[0].replace('\n', '').replace('\t', '')])

                    Contagem += 1

                except:
                    break

            mes = soupOrçamento.find_all("h3",class_= "header")

            dadomes =[]
            listmes = [quote for quote in mes]

            for x in listmes:
                dadomes.append(str(listmes[1]))

            #print(dadomes[0][28:-5])
            #print(tabeladados)
            driver.close()
            mesespecifico += 1

        
            
            
            for x in range(len(tabeladados)):
                tabelafinal.append([dadosjuntos[0][0],dadosjuntos[0][1],dadosjuntos[0][2],dadosjuntos[0][3],
                                            dadosjuntos[0][4],dadosjuntos[0][5],dadomes[0][28:-5],tabeladados[x][0],tabeladados[x][1]])
            
            print(tabelafinal)    
        else:
            break

# %%
print(dadosjuntos[0][0])

# %%
df

# %%
tabelafinal = []

while True:
    try:
        for link in range(len(linktransparencia)):


            #PEGAR O NOME


            option = webdriver.ChromeOptions()
            option.add_argument('headless') 
            option.add_argument("enable-automation");
            option.add_argument("--window-size=1920,1080");
            option.add_argument("--no-sandbox");
            option.add_argument("--disable-extensions");
            option.add_argument("--dns-prefetch-disable");
            option.add_argument("--disable-gpu");
            driver = webdriver.Chrome("C:\WebDriver/chromedriver.exe")
            driver.get(linktransparencia[link])
            driver.find_element_by_xpath(
                "//div[@class='mm-page mm-slideout']//div[@class='js-mmenu-container']//div[@class='container-blocos-deputado']")
            element = driver.find_element_by_xpath(
                "//div[@class='mm-page mm-slideout']//div[@class='js-mmenu-container']//div[@class='container-blocos-deputado']")

            html_content = element.get_attribute("outerHTML")

            soup = BeautifulSoup(html_content,'html.parser')

            mylist = soup.find_all('h2', class_='nome-deputado')

            nome=[]
            for x in mylist:
                nome.append(str(x))
            dados = []
            mylist = soup.find_all('li')
            for item in mylist:
                dados.append(item.text)





            dadosjuntos = [[dados[0].split(":",1)[1],
                            dados[1].split(":",1)[1],
                            dados[2].split(":",1)[1],
                            " ".join(dados[3].split(":",1)[1].replace('\n', '').split()),
                            " ".join(dados[4].split(":",1)[1].replace('\n', '').split()),
                            " ".join(dados[5].split(":",1)[1].replace('\n', '').split())]]

            #print("printar dadosjuntos")
            print("Link {}".format(link))
            driver.close()

            #PEGAR ORÇAMENTO




            for depcode in range(len(linktransparenciames)):
                mesespecifico = 1

                while mesespecifico < 3:
                    linkOrçamento = 'https://www.camara.leg.br/cota-parlamentar/sumarizado?nuDeputadoId={}&dataInicio={}/2020&dataFim={}/2020&despesa=&nomeHospede=&nomePassageiro=&nomeFornecedor=&cnpjFornecedor=&numDocumento=&sguf=&filtroNivel1=1&filtroNivel2=2&filtroNivel3=3'.format(linktransparenciames[depcode],mesespecifico,mesespecifico)
                    option = webdriver.ChromeOptions()
                    option.add_argument('headless') 
                    option.add_argument("enable-automation");
                    option.add_argument("--window-size=1920,1080");
                    option.add_argument("--no-sandbox");
                    option.add_argument("--disable-extensions");
                    option.add_argument("--dns-prefetch-disable");
                    option.add_argument("--disable-gpu");
                    driver = webdriver.Chrome("C:\WebDriver/chromedriver.exe")
                    driver.get(linkOrçamento)
                    driver.find_element_by_xpath(
                        "//div[@class='coluna-centro col-md-9']")
                    elementOrçamento = driver.find_element_by_xpath(
                        "//div[@class='coluna-centro col-md-9']")

                    html_contentOrçamento = elementOrçamento.get_attribute("outerHTML")

                    soupOrçamento = BeautifulSoup(html_contentOrçamento,'html.parser')

                    Contagem = 0
                    tabeladados = []

                    while True:
                        try:
                            TipoDespesa = soupOrçamento.find(id="linkSumarizado{}".format(Contagem))
                            quotes = [quote for quote in TipoDespesa]
                            Despesa = soupOrçamento.find(id="sumarizado{}".format(Contagem))
                            quotes2 = [quote for quote in Despesa]
                            tabeladados.append([quotes[0].replace('\n', '').replace('\t', ''),quotes2[0].replace('\n', '').replace('\t', '')])

                            Contagem += 1

                        except:
                            break

                    mes = soupOrçamento.find_all("h3",class_= "header")

                    dadomes =[]
                    listmes = [quote for quote in mes]

                    for x in listmes:
                        dadomes.append(str(listmes[1]))

                    #print(dadomes[0][28:-5])
                    #print(tabeladados)
                    driver.close()
                    mesespecifico += 1




                    for x in range(len(tabeladados)):
                        tabelafinal.append([dadosjuntos[0][0],dadosjuntos[0][1],dadosjuntos[0][2],dadosjuntos[0][3],
                                                    dadosjuntos[0][4],dadosjuntos[0][5],dadomes[0][28:-5],tabeladados[x][0],tabeladados[x][1]])

                    print(tabelafinal)
                    print([dadosjuntos[0][0],dadomes[0][28:-5]])
                else:
                    break
    except:
        pass

# %%
df = DataFrame(tabelafinal,columns=["Nome civil",'email','Telefone',
                                                        'Endereço','Data de Nascimento','Naturalidade',"Mês","Tipo Despesa","Despesa"])
df
# Out:
#                             Nome civil                                  email  \
# 0               PAULO SERGIO ABOU ANNI             dep.abouanni@camara.leg.br
# 1               PAULO SERGIO ABOU ANNI             dep.abouanni@camara.leg.br
# 2               PAULO SERGIO ABOU ANNI             dep.abouanni@camara.leg.br
# 3               PAULO SERGIO ABOU ANNI             dep.abouanni@camara.leg.br
# 4               PAULO SERGIO ABOU ANNI             dep.abouanni@camara.leg.br
# ..                                 ...                                    ...
# 670   ARTHUR DE OLIVEIRA MAIA DA SILVA   dep.arthuroliveiramaia@camara.leg.br
# 671   ARTHUR DE OLIVEIRA MAIA DA SILVA   dep.arthuroliveiramaia@camara.leg.br
# 672   ARTHUR DE OLIVEIRA MAIA DA SILVA   dep.arthuroliveiramaia@camara.leg.br
# 673   ARTHUR DE OLIVEIRA MAIA DA SILVA   dep.arthuroliveiramaia@camara.leg.br
# 674   ARTHUR DE OLIVEIRA MAIA DA SILVA   dep.arthuroliveiramaia@camara.leg.br
#
# ...
